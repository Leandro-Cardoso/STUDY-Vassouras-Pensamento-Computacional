# %% [markdown]
# <h1>Questão 1</h1>
#
# <pre>
# Desenvolva um programa que solicite ao usuário sua cidade natal:
#
#   - De qual cidade você é?
#
# Após receber a resposta, o programa deve exibir uma mensagem relacionada à cidade fornecida:
#
#   - Cidade maravilhosa! Sempre quis visitar [Nome da cidade]!
# </pre>

# %%
cidade = input('De qual cidade você é? ')

print(f'Cidade maravilhosa! Sempre quis visitar {cidade}!')
# Out:
# De qual cidade você é? Saquarema
# Cidade maravilhosa! Sempre quis visitar Saquarema!

# %% [markdown]
# <h1>Questão 2</h1>
#
# <pre>
# Você foi contratado para desenvolver um programa que ajude o departamento de RH de uma empresa a calcular os bônus de salário para vendedores com base no número de suas vendas mensais. O salário é de R$ 2700.
#
# As regras para o cálculo do novo salário são as seguintes:
#
#   - Se o vendedor realizar entre 100 e menos que 300, ele receberá um bônus de 10% no salário.
#   - Se o vendedor realizar acima de 300 vendas, ele receberá um bônus de 15% no salário.
#   - Caso contrário, o salário do vendedor permanecerá o mesmo salário.
# </pre>

# %%
vendas = float(input('Total de vendas: '))
salario = 2700

if 100 <= vendas < 300:
  bonus = salario * .1
elif vendas >= 300:
  bonus = salario * .15
else:
  bonus = 0

salario_com_bonus = salario + bonus
print(f'Salário com bônus: R$ {salario_com_bonus:.2f}\nBônus: R$ {bonus:.2f}')
# Out:
# Total de vendas: 350
# Salário com bônus: R$ 3105.00
# Bônus: R$ 405.00

# %% [markdown]
# <h1>Questão 3</h1>
#
# <pre>
# Crie um programa o qual o professor digita a nota do aluno de P1, P2, e P3 caso não alcance a média 7 das primeiras provas.
#
#   - Se a média for igual ou maior que 7, deverá informar que este aluno foi aprovado.
#   - Se a média for menor que 7, o aluno vai para a prova final (P3).
#   - Na prova final, se ele tirar nota maior ou igual a 6, ele estará aprovado. Se tirar abaixo, será reprovado.
# </pre>

# %%
p1 = float(input('Nota da P1: '))
p2 = float(input('Nota da P2: '))
p3 = float(input('Nota da P3: '))

media = (p1 + p2) / 2

if media >= 7:
  print(f'Sua média foi de {media:.1f}, você foi aprovado!!!')
elif p3 >= 6:
  print(f'Você precisou realizar a P3 e foi aprovado com {p3:.1f}...')
else:
  print(f'Você precisou realizar a P3 e foi reprovado com {p3:.1f}...')
# Out:
# Nota da P1: 7
# Nota da P2: 9
# Nota da P3: 0
# Sua média foi de 8.0, você foi aprovado!!!

# %% [markdown]
# <h1>Questão 4</h1>
#
# <pre>
# Desenvolva um programa em Python que, para cada uma das variáveis fornecidas abaixo, imprima o nome da variável seguido do seu tipo de dado.
# Por exemplo, para a variável "a", o programa deve imprimir:
#
# a: <tipo_de_dado>
#
# a = 'Ciclano'
# b = '5'
# c = True
# d = 22.0
# e = 12
# </pre>

# %%
a = 'Ciclano'
b = '5'
c = True
d = 22.0
e = 12

print('a:', type(a))
print('b:', type(b))
print('c:', type(c))
print('d:', type(d))
print('e:', type(e))
# Out:
# a: <class 'str'>
# b: <class 'str'>
# c: <class 'bool'>
# d: <class 'float'>
# e: <class 'int'>

# %% [markdown]
# <h1>Questão 5</h1>
#
# <pre>
# Lançado uma série japonesa em animação, em que os personagens de diferentes etinias lutam com armaduras referente a diferentes constelações e que lutam para proteger uma deusa grega da guerra.
# Chegam novos brinquedos da série animada e o lojista resolve aplicar um aumento de 20% nos bonecos da série que custam 120 reais.
# Crie um programa que realize o aumento e forneça o valor com o aumento.
# </pre>

# %%
boneco = 120

aumento = boneco * .2
valor_com_aumento = boneco + aumento

print(f'O valor com aumento do boneco é de R$ {valor_com_aumento:.2f}')
# Out:
# O valor com aumento do boneco é de R$ 144.00

# %% [markdown]
# <h1>Questão 6</h1>
#
# <pre>
# Crie um programa o qual o usuário insere o ano que ele está da faculdade de engenharia de software e é informado quantos anos faltam para ele terminar este curso de 4 anos.
# </pre>

# %%
ano = int(input('Qual ano atual? '))
termino = 2027

faltam = 2027 - ano

print(f'Faltam {faltam} anos, para terminar o curso de Engenharia de Software...')
# Out:
# Qual ano atual? 2023
# Faltam 4 anos, para terminar o curso de Engenharia de Software...

# %% [markdown]
# <h1>Questão 7</h1>
#
# <pre>
# Faça o somatório dos valores a seguir, com um resultado inteiro:
#
# valor_a = '15'
# valor_b = 32.0
# valor_c = 100
# </pre>

# %%
valor_a = '15'
valor_b = 32.0
valor_c = 100

somatorio_inteiro = int(valor_a) + int(valor_b) + valor_c

print('O somatório inteiro é de', somatorio_inteiro)
# Out:
# O somatório inteiro é de 147
